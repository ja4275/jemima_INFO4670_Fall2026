# %% [markdown]
# <a href="https://colab.research.google.com/github/ja4275/jemima_INFO4670_Fall2026/blob/main/Copy_of_INFO4670_Week3_Assignment1_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** \_Jemima Ali_\_    **Date:** \_\_9/6/2026\_\_
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Northgate house style (optional, but keeps your charts consistent)
NAVY = "#22303A"
RUST = "#C0562F"
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]   = (8, 5)
plt.rcParams["axes.titlesize"]   = 13
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.

DATA_DIR = "."   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"

import os
students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly   = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# 1                   9.5      2023-10-19            0
# 2                  19.1      11/16/2022            0
# 3                   8.1      2024-05-03            0
# 4                   6.6      10/24/2022            0

# %%
# how many rows, which columns, what types?
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            2027 non-null   object
#  1   major                 2027 non-null   object
#  2   age                   2027 non-null   int64
#  3   housing               2027 non-null   object
#  4   commute_miles         2027 non-null   float64
#  5   work_hours_per_week   2027 non-null   int64
#  6   advisor_meetings      2027 non-null   int64
#  7   credits_attempted     2027 non-null   int64
#  8   final_gpa             2027 non-null   float64
#  9   study_hours_reported  1772 non-null   float64
#  10  enrollment_date       2027 non-null   object
#  11  dropped_out           2027 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 190.2+ KB

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()
sns.histplot(data=students, x="work_hours_per_week", color=NAVY, ax=ax)   # which chart? which column(s)?
ax.set_title("Work Hours Per Week for Northgate Students")
ax.set_xlabel("Weekly Work Hours")
ax.set_ylabel("Number of Students")
plt.show()

fig, ax = plt.subplots()
sns.boxplot(data=students, y="work_hours_per_week", color=NAVY, ax=ax)
ax.set_title("Northgate Students Work Hours Per Week — box plot")
ax.set_ylabel("Weekly Work Hours")
plt.show()

# %% [markdown]
# **STAR story — Q1** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
#
# *The charts show the work hours of Northgate students per week.*
# - **Track —** which question are you answering?
#
# *The question I am answering is how many hours per week do Northgate students work.*
#
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
#
# *The data indicates that the median is about 18 hours per week. Q1 is about 10 hours, and Q3 seems to be about 25 hours, which results in an IQR of about 15 hours. The maximum is about 40 hours of work, and the minimum is about -12 hours of work. The distribution in the histogram is asymmetrical. Though there are gaps, the histogram has most data in the middle but extends to the right side, so it seems right skewed. There is a very small bar left of -10, separated by empty bins from the rest of the data.*
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# *The negative work hours are unexpected. I would locate this value in the data files to see what is causing this and check its validity and accuracy.*

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
order = students["major"].value_counts().index
fig, ax = plt.subplots()
sns.countplot(data=students, y="major", order = order, color=NAVY, ax=ax)   # which chart? which column(s)?
ax.set_title("Number of Students Per Major in Northgate")
ax.set_xlabel("Number of Students")
ax.set_ylabel("Major")
plt.show()

# %% [markdown]
# **STAR story — Q2** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
#
# *The chart shows the number of student enrollments per major in Northgate.*
#
# - **Track —** which question are you answering?
#
# *The question I am answering is how enrollment compares across majors in Northgate.*
#
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
#
# *The chart says cybersecurity has the most enrollment. The major with the least enrollment seems to be learning technologies. Information science, information technology, data science, and cybersecurity are recorded in two different ways, so it is challenging to compare.*
#
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# *The odd thing about this chart is that information science, information technology, data science, and cybersecurity are recorded in two different ways. I would look at the original data and check for consistency.*

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots(figsize=(9, 5))
sns.boxplot(data=students, x="final_gpa", y="major", color=NAVY, ax=ax)
ax.set_title("Final GPA by Major in Northgate")
ax.set_xlabel("Final GPA")
ax.set_ylabel("Major")
plt.show()

# %% [markdown]
# **STAR story — Q3** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
#
# *The chart shows the box plot of final GPA of students per major for Northgate.*
#
# - **Track —** which question are you answering?
#
# *The question I am answering is how final GPA differs by major.*
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
#
# *The data says that cybersecurity has the highest median, while business analytics has the lowest median if we exclude the multiples of information technology and science. One of the information science has the highest IQR and lowest minimum of all the majors. One of the cybersecurity has the highest maximum of all the majors. All, except for one of the information science category, have an outlier of 0.0 GPA. One of the information science category has 0.0 GPA as a minimum. All the majors overlap with each other, some more than others.*
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# *Information science, information technology, data science, and cybersecurity are recorded in two different ways and have different box plots. I would look at the original data and check for consistency.*

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()
sns.regplot(data=students, x="commute_miles", y="final_gpa",
            scatter_kws={"s": 12, "color": NAVY, "alpha": 0.4},
            line_kws={"color": RUST}, ax=ax)
ax.set_title("Final GPA vs. Commute Miles of Northgate Students")
ax.set_xlabel("Commute Miles")
ax.set_ylabel("Final GPA")
plt.show()

# %% [markdown]
# **STAR story — Q4** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
#
# *The chart shows the relationship between Northgate students' commute miles and their final GPA.*
#
# - **Track —** which question are you answering?
#
# *I am answering whether the final GPA of Northgate students has any relation to their commute miles.*
#
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
#
# *The chart says most commute miles are concentrated between 0 and 10 miles. The final gpa is also kind of concentrated between 2.0 and 3.0. The chart implies a negative association between commute miles and final GPA as the GPA falls with more commute miles. There is a 0.0 GPA streak far from the trendline across about 4 to 41 miles.*
#
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# *The 0.0 streak is unexpected. I would look at the data and check its validity and accuracy.*

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
weekly_avg = weekly.groupby("week")["minutes_active"].mean().reset_index()
fig, ax = plt.subplots()
sns.lineplot(data=weekly_avg, x="week", y="minutes_active",
             color=NAVY, marker="o", ax=ax)
ax.set_title("Average Active Minutes Per Student, by Week, for Northgate")
ax.set_xlabel("Week of semester")
ax.set_ylabel("Avg. minutes active")
plt.show()

# %% [markdown]
# **STAR story — Q5** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
#
# *The chart shows the average weekly active minutes of Northgate students.*
#
# - **Track —** which question are you answering?
#
# *The question I am answering is how engagement of Northgate students changes over the semester.*
#
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
#
# *The chart says engagement remains pretty stable and similar throughout the semester, except for week 9. Week 9 experiences a sharp drop in average active minutes as it goes below 100 minutes.*
#
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# *The sharp drop at week 9 is unexpected. I would look at the original data and check its accuracy to ensure it reflects the actual reality of student engagement.*

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** Is there a relationship between final gpa and the amount of credits attempted by Northgate tudents?

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()
sns.regplot(data=students, x="credits_attempted", y="final_gpa",
            scatter_kws={"s": 12, "color": NAVY, "alpha": 0.4},
            line_kws={"color": RUST}, ax=ax)
ax.set_title("Northgate Students' Final GPA vs. Credits Attempted")
ax.set_xlabel("Credits Attempted")
ax.set_ylabel("Final GPA")
plt.show()

# %% [markdown]
# **STAR story — Part B** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
#
# *The chart shows the relationship between final GPA and the number of credits attempted by Northgate students.
# - **Track —** which question are you answering?
#
# *The question I am answering is whether final GPA and the number of credits attempted have a relationship.
#
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
#
# *There is a slight positive association between Northgate students' final GPA and the number of credits attempted, as final GPA tends to increase slightly with more credits attempted. Final GPA is concentrated between 2.0 and 3.0. The number of credits attempted is concentrated between 20 and 80 credits. There is a 0.0 GPA streak far from the trendline across 0 to about 110 credits attempted.*
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# *It is a bit unexpected that there is a slight positive association between final GPA and credits attempted. It is also odd that there is a 0.0 GPA streak. I would look at the original data and check for accuracy and validity.*

# %% [markdown]
# # Before you submit — checklist
# - [ ] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [ ] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [ ] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [ ] Part B question is written in and answered.
# - [ ] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
